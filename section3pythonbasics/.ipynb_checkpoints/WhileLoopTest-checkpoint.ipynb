# %%
mytext = 'The while loop requires relevant variables to be ready, in this example we need to define an indexing variable, i, which we set to 1.'
mytext_length = len(mytext)

counter = 0
while counter < mytext_length:
    print(mytext[counter])
    counter += 1
# Out:
# T
# h
# e
#
# w
# h
# i
# l
# e
#
# l
# o
# o
# p
#
# r
# e
# q
# u
# i
# r
# e
# s
#
# r
# e
# l
# e
# v
# a
# n
# t
#
# v
# a
# r
# i
# a
# b
# l
# e
# s
#
# t
# o
#
# b
# e
#
# r
# e
# a
# d
# y
# ,
#
# i
# n
#
# t
# h
# i
# s
#
# e
# x
# a
# m
# p
# l
# e
#
# w
# e
#
# n
# e
# e
# d
#
# t
# o
#
# d
# e
# f
# i
# n
# e
#
# a
# n
#
# i
# n
# d
# e
# x
# i
# n
# g
#
# v
# a
# r
# i
# a
# b
# l
# e
# ,
#
# i
# ,
#
# w
# h
# i
# c
# h
#
# w
# e
#
# s
# e
# t
#
# t
# o
#
# 1
# .
